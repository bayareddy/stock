# %%
import fyers_util as fu

fu.authenticate()
# Out:
# https://api-t1.fyers.in/api/v3/generate-authcode?client_id=Z4O9BSFX7K-100&redirect_uri=https%3A%2F%2Fwww.google.com%2F&response_type=code&state=None

# %%
import fyers_util as fu

url="https://www.google.com/?s=ok&code=200&auth_code=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....TiqC1NBCobNxq-TX8lLyhmTsoepdezKgD_AR6OIifIw&state=None"

fu.authorization(url)
# Out:
# token-> eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....zRjQxPxCh1jeDAV2qJQZlnT1jSCRf4vOZOlXT8PC3E0
# Access token updated successfully in File

# %%
#import sys
#sys.path.insert(0, r'D:\\bayareddy\\stock')
import fyers_util as fu
import datetime as dt

if __name__ == "__main__":
    #symbol = "NSE:NIFTY50-INDEX"
    symbol = "NSE:NIFTYMIDCAP50-INDEX"
    time_frame = 'D' 
    range_to = dt.date.today()
    range_from=range_to - dt.timedelta(days=30)
    df = fu.history(symbol, time_frame,range_from, range_to)
    print(df)
# Out:
# {'candles': [[1761264000, 16824.95, 16878.3, 16687.35, 16736.8, 0], [1761523200, 16807.3, 16921.3, 16781.05, 16913.25, 0], [1761609600, 16923.2, 16946.45, 16858.7, 16931.25, 0], [1761696000, 16944.6, 17057.8, 16897.25, 17034.45, 0], [1761782400, 17092.3, 17093.5, 16962.55, 17052.25, 0], [1761868800, 17073.5, 17119.25, 16992.1, 17006.3, 0], [1762128000, 17012.3, 17173.7, 16989.3, 17135.65, 0], [1762214400, 17137.35, 17145.7, 17030, 17048.8, 0], [1762387200, 17069.15, 17082.85, 16908.5, 16931.35, 0], [1762473600, 16887.7, 17053.95, 16741.05, 17030.9, 0], [1762732800, 17051.8, 17152.15, 17019.35, 17097.45, 0], [1762819200, 17137.15, 17208.35, 17011.2, 17196.6, 0], [1762905600, 17289.6, 17385.9, 17276.7, 17339.65, 0], [1762992000, 17362.45, 17415.95, 17256.4, 17281.3, 0], [1763078400, 17293.7, 17366.8, 17220.35, 17299.7, 0], [1763337600, 17374.25, 17454.7, 17347, 17444.5, 0], [1763424000, 17445.2, 17446.9, 17327.15, 17337.65, 0], [1763510400, 17349.65, 17408.6, 17283.2, 17376.8, 0], [1763596800, 17448.6, 17454.6, 17354.4, 17376.35, 0], [1763683200, 17364.55, 17367.7, 17183, 17204.35, 0]], 'code': 200, 'message': '', 's': 'ok'}
